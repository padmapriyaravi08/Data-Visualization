# %%
import matplotlib.pyplot as plt

# %%
x=[101,102,103,104,105,106]
y=[56,69,78,84,86,96]
plt.xlabel("Roll NO")
plt.ylabel("Marks")
plt.xlim(101,105)
plt.ylim(50,100)
plt.plot(x,y,color='orange',linestyle='dashed',linewidth=4,marker='*',markerfacecolor='red',markersize=16)
plt.title("Student Performance")
plt.savefig("practise.png")
plt.show()
