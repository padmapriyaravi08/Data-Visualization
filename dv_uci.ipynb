# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Ibscai06.DGVC-MCA/padmapriya/studentinfo.csv")

# %%
df.isnull()
# Out:
#        code_module  code_presentation  id_student  gender  region  \
# 0            False              False       False   False   False
# 1            False              False       False   False   False
# 2            False              False       False   False   False
# 3            False              False       False   False   False
# 4            False              False       False   False   False
# ...            ...                ...         ...     ...     ...
# 32588        False              False       False   False   False
# 32589        False              False       False   False   False
# 32590        False              False       False   False   False
# 32591        False              False       False   False   False
# 32592        False              False       False   False   False
#
#        highest_education  imd_band  age_band  num_of_prev_attempts  \
# 0                  False     False     False                 False
# ...

# %%
df.isnull().sum()
# Out:
# code_module             2
# code_presentation       5
# id_student              3
# gender                  3
# region                  5
# highest_education       2
# imd_band                2
# age_band                2
# num_of_prev_attempts    0
# studied_credits         2
# disability              0
# final_result            0
# dtype: int64

# %%
df['code_module']=df['code_module'].fillna(0)

# %%
df.isnull().sum()
# Out:
# code_module             0
# code_presentation       5
# id_student              3
# gender                  3
# region                  5
# highest_education       2
# imd_band                2
# age_band                2
# num_of_prev_attempts    0
# studied_credits         2
# disability              0
# final_result            0
# dtype: int64

# %%
mn=df['id_student'].mean()
mn
# Out:
# np.float64(706713.2739183799)

# %%
df['id_student']=df['id_student'].fillna(mn)

# %%
df.isnull().sum()
# Out:
# code_module             0
# code_presentation       5
# id_student              0
# gender                  3
# region                  5
# highest_education       2
# imd_band                2
# age_band                2
# num_of_prev_attempts    0
# studied_credits         2
# disability              0
# final_result            0
# dtype: int64

# %%
md=df['studied_credits'].median()
md
# Out:
# 60.0

# %%
df['studied_credits']=df['studied_credits'].fillna(md)

# %%
df.isnull().sum()
# Out:
# code_module             0
# code_presentation       5
# id_student              0
# gender                  3
# region                  5
# highest_education       2
# imd_band                2
# age_band                2
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64

# %%
mo=df['age_band'].mode()[0]
mo
# Out:
# '0-35'

# %%
df['age_band']=df['age_band'].fillna(mo)

# %%
df.isnull().sum()
# Out:
# code_module             0
# code_presentation       5
# id_student              0
# gender                  3
# region                  5
# highest_education       2
# imd_band                2
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64

# %%
df['highest_education']=df['highest_education'].ffill()
df['highest_education']=df['highest_education'].bfill()
df.isnull().sum()
# Out:
# code_module             0
# code_presentation       5
# id_student              0
# gender                  3
# region                  5
# highest_education       0
# imd_band                2
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64
